# %%
#loading the required packages
#show the plots in the notebook:
# %matplotlib inline 

#this is a great trick to increase resolution of plots:
# %config InlineBackend.figure_format = 'retina'

# %%
#numpy and pandas for data manipulation and computation
import numpy as np
import pandas as pd

#data visualization:
import seaborn as sns
import matplotlib.pyplot as plt

#sklearn is the main machine learning package we will use
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_blobs, make_circles, make_moons
from sklearn.cluster import KMeans
from sklearn import metrics


#set the plot size
from pylab import rcParams
rcParams['figure.figsize'] = 10, 10

# %%
#here x is the original data and y are the classes assigned to each point:
X, y = make_blobs(n_samples=500, n_features=2, centers = 3, cluster_std=1.0, shuffle=False, random_state=42)

#turning the matrix into a dataframe for ease of manipulation:
df = pd.DataFrame(X)
df.columns = ["x", "y"]

# %%
sns.set_style(style = 'darkgrid')
#fit a scatterplot:
sns.lmplot("x", "y", data = df, fit_reg = False, height = 7)

# %%
kmeans = KMeans(n_clusters=3, init="k-means++")

# %%
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
df["clusters"] = kmeans.labels_

# %%
#fit a scatterplot with the dots colored as the clusters assigned by the algorithm:
sns.lmplot("x", "y", data = df, fit_reg = False, hue = "clusters", height = 7)

# %%
metrics.completeness_score(labels_pred=df["clusters"],
                           labels_true=y)
# Out:
# 1.0

# %%
kmeans = KMeans(n_clusters=8)
kmeans.fit(X)
df["clusters"] = kmeans.labels_

# %%
sns.lmplot("x", "y", data = df, fit_reg = False, hue = "cluste", size = 7)
# Out:
# C:\Users\mojta\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
